# %% [markdown]
# <h1><center>第2章 索引</center></h1>

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('data/table.csv',index_col='ID')
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# ## 一、单级索引
# ### 1. loc方法、iloc方法、[]操作符
# #### 最常用的索引方法可能就是这三类，其中iloc表示位置索引，loc表示标签索引，[]也具有很大的便利性，各有特点
# #### （a）loc方法（注意：所有在loc中使用的切片全部包含右端点！）
# #### ① 单行索引：

# %%
df.loc[1103]
# Out:
# School          S_1
# Class           C_1
# Gender            M
# Address    street_2
# Height          186
# Weight           82
# Math           87.2
# Physics          B+
# Name: 1103, dtype: object

# %% [markdown]
# #### ② 多行索引：

# %%
df.loc[[1102,2304]]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 2304    S_2   C_3      F  street_6     164      81  95.5      A-

# %%
df.loc[1304:].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1304    S_1   C_3      M  street_2     195      70  85.2       A
# 1305    S_1   C_3      F  street_5     187      69  61.7      B-
# 2101    S_2   C_1      M  street_7     174      84  83.3       C
# 2102    S_2   C_1      F  street_6     161      61  50.6      B+
# 2103    S_2   C_1      M  street_4     157      61  52.5      B-

# %%
df.loc[2402::-1].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2402    S_2   C_4      M  street_7     166      82  48.7       B
# 2401    S_2   C_4      F  street_2     192      62  45.3       A
# 2305    S_2   C_3      M  street_4     187      73  48.9       B
# 2304    S_2   C_3      F  street_6     164      81  95.5      A-
# 2303    S_2   C_3      F  street_7     190      99  65.9       C

# %% [markdown]
# #### ③ 单列索引：

# %%
df.loc[:,'Height'].head()
# Out:
# ID
# 1101    173
# 1102    192
# 1103    186
# 1104    167
# 1105    159
# Name: Height, dtype: int64

# %% [markdown]
# #### ④ 多列索引：

# %%
df.loc[:,['Height','Math']].head()
# Out:
#       Height  Math
# ID
# 1101     173  34.0
# 1102     192  32.5
# 1103     186  87.2
# 1104     167  80.4
# 1105     159  84.8

# %%
df.loc[:,'Height':'Math'].head()
# Out:
#       Height  Weight  Math
# ID
# 1101     173      63  34.0
# 1102     192      73  32.5
# 1103     186      82  87.2
# 1104     167      81  80.4
# 1105     159      64  84.8

# %% [markdown]
# #### ⑤ 联合索引：

# %%
df.loc[1102:2401:3,'Height':'Math'].head()
# Out:
#       Height  Weight  Math
# ID
# 1102     192      73  32.5
# 1105     159      64  84.8
# 1203     160      53  58.8
# 1301     161      68  31.5
# 1304     195      70  85.2

# %% [markdown]
# #### ⑥ 函数式索引：

# %%
df.loc[lambda x:x['Gender']=='M'].head()
#loc中使用的函数，传入参数就是前面的df
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+

# %%
def f(x):
    return [1101,1103]
df.loc[f]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+

# %% [markdown]
# #### ⑦ 布尔索引（将重点在第2节介绍）

# %%
df.loc[df['Address'].isin(['street_7','street_4'])].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 2101    S_2   C_1      M  street_7     174      84  83.3       C

# %%
df.loc[[True if i[-1]=='4' or i[-1]=='7' else False for i in df['Address'].values]].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 2101    S_2   C_1      M  street_7     174      84  83.3       C

# %% [markdown]
# #### 小节：本质上说，loc中能传入的只有布尔列表和索引子集构成的列表，只要把握这个原则就很容易理解上面那些操作
# #### （b）iloc方法（注意与loc不同，切片右端点不包含）
# #### ① 单行索引：

# %%
df.iloc[3]
# Out:
# School          S_1
# Class           C_1
# Gender            F
# Address    street_2
# Height          167
# Weight           81
# Math           80.4
# Physics          B-
# Name: 1104, dtype: object

# %% [markdown]
# #### ② 多行索引：

# %%
df.iloc[3:5]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### ③ 单列索引：

# %%
df.iloc[:,3].head()
# Out:
# ID
# 1101    street_1
# 1102    street_2
# 1103    street_2
# 1104    street_2
# 1105    street_4
# Name: Address, dtype: object

# %% [markdown]
# #### ④ 多列索引：

# %%
df.iloc[:,7::-2].head()
# Out:
#      Physics  Weight   Address Class
# ID
# 1101      A+      63  street_1   C_1
# 1102      B+      73  street_2   C_1
# 1103      B+      82  street_2   C_1
# 1104      B-      81  street_2   C_1
# 1105      B+      64  street_4   C_1

# %% [markdown]
# #### ⑤ 混合索引：

# %%
df.iloc[3::4,7::-2].head()
# Out:
#      Physics  Weight   Address Class
# ID
# 1104      B-      81  street_2   C_1
# 1203      A+      53  street_6   C_2
# 1302      A-      57  street_1   C_3
# 2101       C      84  street_7   C_1
# 2105       A      81  street_4   C_1

# %% [markdown]
# #### ⑥ 函数式索引：

# %%
df.iloc[lambda x:[3]].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-

# %% [markdown]
# #### 小节：由上所述，iloc中接收的参数只能为整数或整数列表，不能使用布尔索引
# ### 3. []操作符
# #### 如果不想陷入困境，请不要在行索引为浮点时使用[]操作符，因为在Series中的浮点[]并不是进行位置比较，而是值比较，非常特殊
# #### （a）Series的[]操作
# #### ① 单元素索引：

# %%
s = pd.Series(df['Math'],index=df.index)
s[1101]
#使用的是索引标签
# Out:
# 34.0

# %% [markdown]
# #### ② 多行索引：

# %%
s[0:4]
#使用的是绝对位置的整数切片，与元素无关，这里容易混淆
# Out:
# ID
# 1101    34.0
# 1102    32.5
# 1103    87.2
# 1104    80.4
# Name: Math, dtype: float64

# %% [markdown]
# #### ③ 函数式索引：

# %%
s[lambda x: x.index[16::-6]]
#注意使用lambda函数时，直接切片(如：s[lambda x: 16::-6])就报错，此时使用的不是绝对位置切片，而是元素切片，非常易错
# Out:
# ID
# 2102    50.6
# 1301    31.5
# 1105    84.8
# Name: Math, dtype: float64

# %% [markdown]
# #### ④ 布尔索引：

# %%
s[s>80]
# Out:
# ID
# 1103    87.2
# 1104    80.4
# 1105    84.8
# 1201    97.0
# 1302    87.7
# 1304    85.2
# 2101    83.3
# 2205    85.4
# 2304    95.5
# Name: Math, dtype: float64

# %% [markdown]
# #### （b）DataFrame的[]操作
# #### ① 单行索引：

# %%
df[1:2]
#这里非常容易写成df['label']，会报错
#同Series使用了绝对位置切片
#如果想要获得某一个元素，可用如下get_loc方法：
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+

# %%
row = df.index.get_loc(1102)
df[row:row+1]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+

# %% [markdown]
# #### ② 多行索引：

# %%
#用切片，如果是选取指定的某几行，推荐使用loc，否则很可能报错
df[3:5]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### ③ 单列索引：

# %%
df['School'].head()
# Out:
# ID
# 1101    S_1
# 1102    S_1
# 1103    S_1
# 1104    S_1
# 1105    S_1
# Name: School, dtype: object

# %% [markdown]
# #### ④ 多列索引：

# %%
df[['School','Math']].head()
# Out:
#      School  Math
# ID
# 1101    S_1  34.0
# 1102    S_1  32.5
# 1103    S_1  87.2
# 1104    S_1  80.4
# 1105    S_1  84.8

# %% [markdown]
# #### ⑤函数式索引：

# %%
df[lambda x:['Math','Physics']].head()
# Out:
#       Math Physics
# ID
# 1101  34.0      A+
# 1102  32.5      B+
# 1103  87.2      B+
# 1104  80.4      B-
# 1105  84.8      B+

# %% [markdown]
# #### ⑥ 布尔索引：

# %%
df[df['Gender']=='F'].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1204    S_1   C_2      F  street_5     162      63  33.8       B

# %% [markdown]
# #### 小节：一般来说，[]操作符常用于列选择或布尔选择，尽量避免行的选择
# ### 2. 布尔索引
# #### （a）布尔符号：'&','|','~'：分别代表和and，或or，取反not

# %%
df[(df['Gender']=='F')&(df['Address']=='street_2')].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 2401    S_2   C_4      F  street_2     192      62  45.3       A
# 2404    S_2   C_4      F  street_2     160      84  67.7       B

# %%
df[(df['Math']>85)|(df['Address']=='street_7')].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1302    S_1   C_3      F  street_1     175      57  87.7      A-
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 1304    S_1   C_3      M  street_2     195      70  85.2       A

# %%
df[~((df['Math']>75)|(df['Address']=='street_1'))].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1204    S_1   C_2      F  street_5     162      63  33.8       B
# 1205    S_1   C_2      F  street_6     167      63  68.4      B-

# %% [markdown]
# #### loc和[]中相应位置都能使用布尔列表选择：

# %%
df.loc[df['Math']>60,(df[:8]['Address']=='street_6').values].head()
#如果不加values就会索引对齐发生错误，Pandas中的索引对齐是一个重要特征，很多时候非常使用
#但是若不加以留意，就会埋下隐患
# Out:
#      Physics
# ID
# 1103      B+
# 1104      B-
# 1105      B+
# 1201      A-
# 1202      B-

# %% [markdown]
# #### （b） isin方法

# %%
df[df['Address'].isin(['street_1','street_4'])&df['Physics'].isin(['A','A+'])]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 2105    S_2   C_1      M  street_4     170      81  34.2       A
# 2203    S_2   C_2      M  street_4     155      91  73.8      A+

# %%
#上面也可以用字典方式写：
df[df[['Address','Physics']].isin({'Address':['street_1','street_4'],'Physics':['A','A+']}).all(1)]
#all与&的思路是类似的，其中的1代表按照跨列方向判断是否全为True
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 2105    S_2   C_1      M  street_4     170      81  34.2       A
# 2203    S_2   C_2      M  street_4     155      91  73.8      A+

# %% [markdown]
# ### 3. 快速标量索引
# #### 当只需要取一个元素时，at和iat方法能够提供更快的实现：

# %%
display(df.at[1101,'School'])
display(df.loc[1101,'School'])
display(df.iat[0,0])
display(df.iloc[0,0])
#可尝试去掉注释对比时间
#%timeit df.at[1101,'School']
#%timeit df.loc[1101,'School']
#%timeit df.iat[0,0]
#%timeit df.iloc[0,0]
# Out:
# 'S_1'
# 'S_1'
# 'S_1'
# 'S_1'

# %% [markdown]
# ### 4. 区间索引
# #### 此处介绍并不是说只能在单级索引中使用区间索引，只是作为一种特殊类型的索引方式，在此处先行介绍
# #### （1）利用interval_range方法

# %%
pd.interval_range(start=0,end=5)
#closed参数可选'left''right''both''neither'，默认左开右闭
# Out:
# IntervalIndex([(0, 1], (1, 2], (2, 3], (3, 4], (4, 5]],
#               closed='right',
#               dtype='interval[int64]')

# %%
pd.interval_range(start=0,periods=8,freq=5)
#periods参数控制区间个数，freq控制步长
# Out:
# IntervalIndex([(0, 5], (5, 10], (10, 15], (15, 20], (20, 25], (25, 30], (30, 35], (35, 40]],
#               closed='right',
#               dtype='interval[int64]')

# %% [markdown]
# #### （2）利用cut将数值列转为区间列，例如统计数学成绩的区间情况：

# %%
i1 = pd.Interval(0,40)
i2 = pd.Interval(40,60)
i3 = pd.Interval(60,80)
i4 = pd.Interval(80,100)
bins = pd.IntervalIndex([i1,i2,i3,i4])
math_interval = pd.cut(df['Math'],bins=bins).astype('interval')
#注意，如果没有类型转换，此时并不是区间类型，而是category类型
math_interval.head()
# Out:
# ID
# 1101      (0, 40]
# 1102      (0, 40]
# 1103    (80, 100]
# 1104    (80, 100]
# 1105    (80, 100]
# Name: Math, dtype: interval

# %% [markdown]
# #### （3）区间索引的选取

# %%
df_i = df.join(math_interval,rsuffix='_interval')[['Math','Math_interval']]\
            .reset_index().set_index('Math_interval')
df_i.head()
# Out:
#                  ID  Math
# Math_interval
# (0, 40]        1101  34.0
# (0, 40]        1102  32.5
# (80, 100]      1103  87.2
# (80, 100]      1104  80.4
# (80, 100]      1105  84.8

# %%
df_i.loc[65].head()
#包含该值就会被选中
# Out:
#                  ID  Math
# Math_interval
# (60, 80]       1202  63.5
# (60, 80]       1205  68.4
# (60, 80]       1305  61.7
# (60, 80]       2104  72.2
# (60, 80]       2202  68.5

# %%
df_i.loc[[65,90]].head()
# Out:
#                  ID  Math
# Math_interval
# (60, 80]       1202  63.5
# (60, 80]       1205  68.4
# (60, 80]       1305  61.7
# (60, 80]       2104  72.2
# (60, 80]       2202  68.5

# %% [markdown]
# #### 如果想要选取某个区间，可以使用overlap方法：

# %%
#df_i.loc[pd.Interval(70,75)].head() 报错
df_i[df_i.index.overlaps(pd.Interval(70, 85))].head()
# Out:
#                  ID  Math
# Math_interval
# (80, 100]      1103  87.2
# (80, 100]      1104  80.4
# (80, 100]      1105  84.8
# (80, 100]      1201  97.0
# (60, 80]       1202  63.5

# %% [markdown]
# ## 二、多级索引
# ### 1. 创建多级索引
# #### （a）通过from_tuple或from_arrays
# #### ① 直接创建元组

# %%
tuples = [('A','a'),('A','b'),('B','a'),('B','b')]
mul_index = pd.MultiIndex.from_tuples(tuples, names=('Upper', 'Lower'))
mul_index
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %%
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %% [markdown]
# #### ② 利用zip创建元组

# %%
L1 = list('AABB')
L2 = list('abab')
tuples = list(zip(L1,L2))
mul_index = pd.MultiIndex.from_tuples(tuples, names=('Upper', 'Lower'))
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %% [markdown]
# #### ③ 通过Array创建

# %%
arrays = [['A','a'],['A','b'],['B','a'],['B','b']]
mul_index = pd.MultiIndex.from_tuples(arrays, names=('Upper', 'Lower'))
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %%
mul_index
#由此看出内部自动转成元组
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %% [markdown]
# #### （b）通过from_product

# %%
L1 = ['A','B']
L2 = ['a','b']
pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
#两两相乘
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %% [markdown]
# #### （c）指定df中的列创建（set_index方法）

# %%
df_using_mul = df.set_index(['Class','Address'])
df_using_mul.head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_1   street_1    S_1      M     173      63  34.0      A+
#       street_2    S_1      F     192      73  32.5      B+
#       street_2    S_1      M     186      82  87.2      B+
#       street_2    S_1      F     167      81  80.4      B-
#       street_4    S_1      F     159      64  84.8      B+

# %% [markdown]
# ### 2. 索引名修改

# %%
df_mul = pd.DataFrame(np.random.rand(4,4),
                      columns=pd.MultiIndex.from_product([['A','B'],['a','b']],names=('Upper', 'Lower')),
                      index=pd.MultiIndex.from_product([['C','D'],['c','d']],names=('Big', 'Small')),)
df_mul
# Out:
# Upper             A                   B
# Lower             a         b         a         b
# Big Small
# C   c      0.225775  0.607668  0.921949  0.260423
#     d      0.838633  0.348683  0.744271  0.680483
# D   c      0.224721  0.056473  0.587502  0.707289
#     d      0.249432  0.822590  0.806103  0.921521

# %%
df_mul.rename_axis(index={'Big':'Supper Big'},columns={'Lower':'Extremely Low'})
# Out:
# Upper                    A                   B
# Extremely Low            a         b         a         b
# Supper Big Small
# C          c      0.225775  0.607668  0.921949  0.260423
#            d      0.838633  0.348683  0.744271  0.680483
# D          c      0.224721  0.056473  0.587502  0.707289
#            d      0.249432  0.822590  0.806103  0.921521

# %% [markdown]
# ### 3. 多层索引切片

# %%
df_using_mul.head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_1   street_1    S_1      M     173      63  34.0      A+
#       street_2    S_1      F     192      73  32.5      B+
#       street_2    S_1      M     186      82  87.2      B+
#       street_2    S_1      F     167      81  80.4      B-
#       street_4    S_1      F     159      64  84.8      B+

# %% [markdown]
# #### （a）一般切片

# %%
#df_using_mul.loc['C_2','street_5']
#当索引不排序时，单个索引会报出性能警告
#df_using_mul.index.is_lexsorted()
#该函数检查是否排序
df_using_mul.sort_index().loc['C_2','street_5']
#df_using_mul.sort_index().index.is_lexsorted()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_5    S_1      M     188      68  97.0      A-
#       street_5    S_1      F     162      63  33.8       B
#       street_5    S_2      M     193     100  39.1       B

# %%
#df_using_mul.loc[('C_2','street_5'):] 报错
#当不排序时，不能使用多层切片
df_using_mul.sort_index().loc[('C_2','street_6'):('C_3','street_4')]
#注意此处由于使用了loc，因此仍然包含右端点
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_6    S_1      M     160      53  58.8      A+
#       street_6    S_1      F     167      63  68.4      B-
#       street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_1    S_1      F     175      57  87.7      A-
#       street_2    S_1      M     195      70  85.2       A
#       street_4    S_1      M     161      68  31.5      B+
#       street_4    S_2      F     157      78  72.3      B+
#       street_4    S_2      M     187      73  48.9       B

# %%
df_using_mul.sort_index().loc[('C_2','street_7'):'C_3'].head()
#非元组也是合法的，表示选中该层所有元素
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_1    S_1      F     175      57  87.7      A-
#       street_2    S_1      M     195      70  85.2       A
#       street_4    S_1      M     161      68  31.5      B+

# %% [markdown]
# #### （b）第一类特殊情况：由元组构成列表

# %%
df_using_mul.sort_index().loc[[('C_2','street_7'),('C_3','street_2')]]
#表示选出某几个元素，精确到最内层索引
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_2    S_1      M     195      70  85.2       A

# %% [markdown]
# #### （c）第二类特殊情况：由列表构成元组（只能应用于Series）

# %%
df_using_mul['School'].sort_index().loc[(['C_2','C_3'],['street_4','street_7'])]
#选出第一层在‘C_2’和'C_3'中且第二层在'street_4'和'street_7'中的行
# Out:
# Class  Address
# C_2    street_4    S_1
#        street_4    S_2
#        street_7    S_2
#        street_7    S_2
# C_3    street_4    S_1
#        street_4    S_2
#        street_4    S_2
#        street_7    S_1
#        street_7    S_2
# Name: School, dtype: object

# %% [markdown]
# ### 4. 多层索引中的slice对象

# %%
L1,L2 = ['A','B','C'],['a','b','c']
mul_index1 = pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
L3,L4 = ['D','E','F'],['d','e','f']
mul_index2 = pd.MultiIndex.from_product([L3,L4],names=('Big', 'Small'))
df_s = pd.DataFrame(np.random.rand(9,9),index=mul_index1,columns=mul_index2)
df_s
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     a      0.412294  0.856048  0.593020  0.350369  0.393234  0.541000
#       b      0.560429  0.330450  0.767018  0.125737  0.986267  0.095413
#       c      0.286233  0.608784  0.687702  0.572872  0.839715  0.670709
# B     a      0.125153  0.880828  0.191077  0.046600  0.406655  0.701778
#       b      0.888529  0.811094  0.443152  0.567987  0.944995  0.255137
#       c      0.304480  0.509145  0.628148  0.387255  0.923120  0.173314
# C     a      0.252447  0.792853  0.197357  0.412084  0.387532  0.535832
#       b      0.971194  0.930946  0.454574  0.627929  0.117895  0.375075
#       c      0.234391  0.498079  0.446496  0.015544  0.549823  0.875670
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     a      0.274753  0.546031  0.047053
#       b      0.122475  0.517818  0.587932
#       c      0.499149  0.824682  0.191891
# B     a      0.140026  0.702590  0.256940
#       b      0.523808  0.445340  0.439672
#       c      0.608862  0.786831  0.467263
# C     a      0.004658  0.323290  0.595518
#       b      0.031119  0.917977  0.225203
#       c      0.248863  0.817206  0.845806

# %%
idx=pd.IndexSlice

# %% [markdown]
# #### 索引Slice的使用非常灵活：

# %%
df_s.loc[idx['B':,df_s['D']['d']>0.3],idx[df_s.sum()>4]]
#df_s.sum()默认为对列求和，因此返回一个长度为9的数值列表
# Out:
# Big                 D                             E                   F
# Small               d         e         f         e         f         e
# Upper Lower
# B     b      0.888529  0.811094  0.443152  0.944995  0.255137  0.445340
#       c      0.304480  0.509145  0.628148  0.923120  0.173314  0.786831
# C     b      0.971194  0.930946  0.454574  0.117895  0.375075  0.917977

# %% [markdown]
# ### 5. 索引层的交换
# #### （a）swaplevel方法（两层交换）

# %%
df_using_mul.head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_1   street_1    S_1      M     173      63  34.0      A+
#       street_2    S_1      F     192      73  32.5      B+
#       street_2    S_1      M     186      82  87.2      B+
#       street_2    S_1      F     167      81  80.4      B-
#       street_4    S_1      F     159      64  84.8      B+

# %%
df_using_mul.swaplevel(i=1,j=0,axis=0).sort_index().head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Address  Class
# street_1 C_1      S_1      M     173      63  34.0      A+
#          C_2      S_2      M     175      74  47.2      B-
#          C_3      S_1      F     175      57  87.7      A-
# street_2 C_1      S_1      F     192      73  32.5      B+
#          C_1      S_1      M     186      82  87.2      B+

# %% [markdown]
# #### （b）reorder_levels方法（多层交换）

# %%
df_muls = df.set_index(['School','Class','Address'])
df_muls.head()
# Out:
#                       Gender  Height  Weight  Math Physics
# School Class Address
# S_1    C_1   street_1      M     173      63  34.0      A+
#              street_2      F     192      73  32.5      B+
#              street_2      M     186      82  87.2      B+
#              street_2      F     167      81  80.4      B-
#              street_4      F     159      64  84.8      B+

# %%
df_muls.reorder_levels([2,0,1],axis=0).sort_index().head()
# Out:
#                       Gender  Height  Weight  Math Physics
# Address  School Class
# street_1 S_1    C_1        M     173      63  34.0      A+
#                 C_3        F     175      57  87.7      A-
#          S_2    C_2        M     175      74  47.2      B-
# street_2 S_1    C_1        F     192      73  32.5      B+
#                 C_1        M     186      82  87.2      B+

# %%
#如果索引有name，可以直接使用name
df_muls.reorder_levels(['Address','School','Class'],axis=0).sort_index().head()
# Out:
#                       Gender  Height  Weight  Math Physics
# Address  School Class
# street_1 S_1    C_1        M     173      63  34.0      A+
#                 C_3        F     175      57  87.7      A-
#          S_2    C_2        M     175      74  47.2      B-
# street_2 S_1    C_1        F     192      73  32.5      B+
#                 C_1        M     186      82  87.2      B+

# %% [markdown]
# ## 三、索引设定
# ### 1. index_col参数
# #### index_col是read_csv中的一个参数，而不是某一个方法：

# %%
pd.read_csv('data/table.csv',index_col=['Address','School']).head()
# Out:
#                 Class    ID Gender  Height  Weight  Math Physics
# Address  School
# street_1 S_1      C_1  1101      M     173      63  34.0      A+
# street_2 S_1      C_1  1102      F     192      73  32.5      B+
#          S_1      C_1  1103      M     186      82  87.2      B+
#          S_1      C_1  1104      F     167      81  80.4      B-
# street_4 S_1      C_1  1105      F     159      64  84.8      B+

# %% [markdown]
# ### 2. reindex方法
# #### reindex是指重新索引，它的重要特性在于索引对齐，很多时候用于重新排序

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.reindex(index=[1101,1203,1206,2402])
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1   173.0    63.0  34.0      A+
# 1203    S_1   C_2      M  street_6   160.0    53.0  58.8      A+
# 1206    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN
# 2402    S_2   C_4      M  street_7   166.0    82.0  48.7       B

# %%
df.reindex(columns=['Height','Gender','Average']).head()
# Out:
#       Height Gender  Average
# ID
# 1101     173      M      NaN
# 1102     192      F      NaN
# 1103     186      M      NaN
# 1104     167      F      NaN
# 1105     159      F      NaN

# %% [markdown]
# #### 可以选择缺失值的填充方法：fill_value和method（bfill/ffill/nearest），其中method参数必须索引单调

# %%
df.reindex(index=[1101,1203,1206,2402],method='bfill')
#bfill表示用所在索引1206的后一个有效行填充，ffill为前一个有效行，nearest是指最近的
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1206    S_1   C_3      M  street_4     161      68  31.5      B+
# 2402    S_2   C_4      M  street_7     166      82  48.7       B

# %%
df.reindex(index=[1101,1203,1206,2402],method='nearest')
#数值上1205比1301更接近1206，因此用前者填充
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1206    S_1   C_2      F  street_6     167      63  68.4      B-
# 2402    S_2   C_4      M  street_7     166      82  48.7       B

# %% [markdown]
# ### 3. reindex_like方法
# #### 作用为生成一个横纵索引完全与参数列表一致的DataFrame，数据使用被调用的表

# %%
df_temp = pd.DataFrame({'Weight':np.zeros(5),
                        'Height':np.zeros(5),
                        'ID':[1101,1104,1103,1106,1102]}).set_index('ID')
df_temp.reindex_like(df[0:5][['Weight','Height']])
# Out:
#       Weight  Height
# ID
# 1101     0.0     0.0
# 1102     0.0     0.0
# 1103     0.0     0.0
# 1104     0.0     0.0
# 1105     NaN     NaN

# %% [markdown]
# #### 如果df_temp单调还可以使用method参数：

# %%
df_temp = pd.DataFrame({'Weight':range(5),
                        'Height':range(5),
                        'ID':[1101,1104,1103,1106,1102]}).set_index('ID').sort_index()
df_temp.reindex_like(df[0:5][['Weight','Height']],method='bfill')
#可以自行检验这里的1105的值是否是由bfill规则填充
# Out:
#       Weight  Height
# ID
# 1101       0       0
# 1102       4       4
# 1103       2       2
# 1104       1       1
# 1105       3       3

# %% [markdown]
# ### 4. set_index方法

# %% [markdown]
# #### （a）使用表内列作为索引：

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.set_index('Class').head()
# Out:
#       School Gender   Address  Height  Weight  Math Physics
# Class
# C_1      S_1      M  street_1     173      63  34.0      A+
# C_1      S_1      F  street_2     192      73  32.5      B+
# C_1      S_1      M  street_2     186      82  87.2      B+
# C_1      S_1      F  street_2     167      81  80.4      B-
# C_1      S_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 利用append参数可以将当前索引维持不变

# %%
df.set_index('Class',append=True).head()
# Out:
#            School Gender   Address  Height  Weight  Math Physics
# ID   Class
# 1101 C_1      S_1      M  street_1     173      63  34.0      A+
# 1102 C_1      S_1      F  street_2     192      73  32.5      B+
# 1103 C_1      S_1      M  street_2     186      82  87.2      B+
# 1104 C_1      S_1      F  street_2     167      81  80.4      B-
# 1105 C_1      S_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### （b）使用与表长相同的列作为索引（需要先转化为Series，否则报错）：

# %%
df.set_index(pd.Series(range(df.shape[0]))).head()
# Out:
#   School Class Gender   Address  Height  Weight  Math Physics
# 0    S_1   C_1      M  street_1     173      63  34.0      A+
# 1    S_1   C_1      F  street_2     192      73  32.5      B+
# 2    S_1   C_1      M  street_2     186      82  87.2      B+
# 3    S_1   C_1      F  street_2     167      81  80.4      B-
# 4    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 可以直接添加多级索引：

# %%
df.set_index([pd.Series(range(df.shape[0])),pd.Series(np.ones(df.shape[0]))]).head()
# Out:
#       School Class Gender   Address  Height  Weight  Math Physics
# 0 1.0    S_1   C_1      M  street_1     173      63  34.0      A+
# 1 1.0    S_1   C_1      F  street_2     192      73  32.5      B+
# 2 1.0    S_1   C_1      M  street_2     186      82  87.2      B+
# 3 1.0    S_1   C_1      F  street_2     167      81  80.4      B-
# 4 1.0    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# ### 5. reset_index方法
# #### 默认状态直接恢复到自然数索引：

# %%
df.reset_index().head()
# Out:
#      ID School Class Gender   Address  Height  Weight  Math Physics
# 0  1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1  1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 2  1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 3  1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 4  1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 用level参数指定哪一层被reset，用col_level参数指定set到哪一层：

# %%
L1,L2 = ['A','B','C'],['a','b','c']
mul_index1 = pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
L3,L4 = ['D','E','F'],['d','e','f']
mul_index2 = pd.MultiIndex.from_product([L3,L4],names=('Big', 'Small'))
df_temp = pd.DataFrame(np.random.rand(9,9),index=mul_index1,columns=mul_index2)
df_temp.head()
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     a      0.635311  0.249110  0.520459  0.268670  0.378372  0.562006
#       b      0.890127  0.735009  0.124944  0.335544  0.577843  0.454673
#       c      0.322743  0.311879  0.816199  0.338342  0.334737  0.052886
# B     a      0.829814  0.775140  0.755466  0.803066  0.037107  0.990076
#       b      0.103740  0.129165  0.134986  0.867719  0.445232  0.548640
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     a      0.438763  0.286718  0.906132
#       b      0.651714  0.254596  0.209258
#       c      0.367229  0.793003  0.012600
# B     a      0.652910  0.443399  0.342148
#       b      0.149589  0.999655  0.517430

# %%
df_temp1 = df_temp.reset_index(level=1,col_level=1)
df_temp1.head()
# Out:
# Big                 D                             E                      \
# Small Lower         d         e         f         d         e         f
# Upper
# A         a  0.635311  0.249110  0.520459  0.268670  0.378372  0.562006
# A         b  0.890127  0.735009  0.124944  0.335544  0.577843  0.454673
# A         c  0.322743  0.311879  0.816199  0.338342  0.334737  0.052886
# B         a  0.829814  0.775140  0.755466  0.803066  0.037107  0.990076
# B         b  0.103740  0.129165  0.134986  0.867719  0.445232  0.548640
#
# Big           F
# Small         d         e         f
# Upper
# A      0.438763  0.286718  0.906132
# A      0.651714  0.254596  0.209258
# A      0.367229  0.793003  0.012600
# B      0.652910  0.443399  0.342148
# B      0.149589  0.999655  0.517430

# %%
df_temp1.columns
#看到的确插入了level2
# Out:
# MultiIndex([( '', 'Lower'),
#             ('D',     'd'),
#             ('D',     'e'),
#             ('D',     'f'),
#             ('E',     'd'),
#             ('E',     'e'),
#             ('E',     'f'),
#             ('F',     'd'),
#             ('F',     'e'),
#             ('F',     'f')],
#            names=['Big', 'Small'])

# %%
df_temp1.index
#最内层索引被移出
# Out:
# Index(['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'], dtype='object', name='Upper')

# %% [markdown]
# ### 6. rename方法
# #### 在多层索引中已经介绍过了rename_axis，此处rename方法用于修改列或者行索引标签，而不是索引名：

# %%
df_temp.rename(index={'A':'T'},columns={'e':'changed_e'}).head()
# Out:
# Big                 D                             E                      \
# Small               d changed_e         f         d changed_e         f
# Upper Lower
# T     a      0.635311  0.249110  0.520459  0.268670  0.378372  0.562006
#       b      0.890127  0.735009  0.124944  0.335544  0.577843  0.454673
#       c      0.322743  0.311879  0.816199  0.338342  0.334737  0.052886
# B     a      0.829814  0.775140  0.755466  0.803066  0.037107  0.990076
#       b      0.103740  0.129165  0.134986  0.867719  0.445232  0.548640
#
# Big                 F
# Small               d changed_e         f
# Upper Lower
# T     a      0.438763  0.286718  0.906132
#       b      0.651714  0.254596  0.209258
#       c      0.367229  0.793003  0.012600
# B     a      0.652910  0.443399  0.342148
#       b      0.149589  0.999655  0.517430

# %% [markdown]
# ## 四、常用索引型函数
# ### 1. where函数
# #### 当对条件为False的单元进行填充：

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.where(df['Gender']=='M').head()
#不满足条件的行全部被设置为NaN
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1   173.0    63.0  34.0      A+
# 1102    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN
# 1103    S_1   C_1      M  street_2   186.0    82.0  87.2      B+
# 1104    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN
# 1105    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN

# %% [markdown]
# #### 通过这种方法筛选结果和[]操作符的结果完全一致：

# %%
df.where(df['Gender']=='M').dropna().head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1   173.0    63.0  34.0      A+
# 1103    S_1   C_1      M  street_2   186.0    82.0  87.2      B+
# 1201    S_1   C_2      M  street_5   188.0    68.0  97.0      A-
# 1203    S_1   C_2      M  street_6   160.0    53.0  58.8      A+
# 1301    S_1   C_3      M  street_4   161.0    68.0  31.5      B+

# %% [markdown]
# #### 第一个参数为布尔条件，第二个参数为填充值：

# %%
df.where(df['Gender']=='M',np.random.rand(df.shape[0],df.shape[1])).head()
# Out:
#          School     Class    Gender    Address      Height     Weight  \
# ID
# 1101        S_1       C_1         M   street_1  173.000000  63.000000
# 1102   0.517827  0.802328  0.807916  0.0736298    0.162586   0.584318
# 1103        S_1       C_1         M   street_2  186.000000  82.000000
# 1104  0.0275598  0.846608  0.116255  0.0523699    0.329443   0.611595
# 1105   0.809269  0.167443  0.463554   0.845336    0.817965   0.647089
#
#            Math   Physics
# ID
# 1101  34.000000        A+
# 1102   0.292493  0.651248
# 1103  87.200000        B+
# 1104   0.804229  0.294602
# 1105   0.634862  0.866162

# %% [markdown]
# ### 2. mask函数
# #### mask函数与where功能上相反，其余完全一致，即对条件为True的单元进行填充

# %%
df.mask(df['Gender']=='M').dropna().head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2   192.0    73.0  32.5      B+
# 1104    S_1   C_1      F  street_2   167.0    81.0  80.4      B-
# 1105    S_1   C_1      F  street_4   159.0    64.0  84.8      B+
# 1202    S_1   C_2      F  street_4   176.0    94.0  63.5      B-
# 1204    S_1   C_2      F  street_5   162.0    63.0  33.8       B

# %%
df.mask(df['Gender']=='M',np.random.rand(df.shape[0],df.shape[1])).head()
# Out:
#         School     Class     Gender   Address      Height     Weight  \
# ID
# 1101  0.761856    0.5916  0.0931594  0.545003    0.598628   0.004015
# 1102       S_1       C_1          F  street_2  192.000000  73.000000
# 1103  0.325567  0.852542   0.705248  0.924892    0.880923   0.228709
# 1104       S_1       C_1          F  street_2  167.000000  81.000000
# 1105       S_1       C_1          F  street_4  159.000000  64.000000
#
#            Math   Physics
# ID
# 1101   0.791393  0.266685
# 1102  32.500000        B+
# 1103   0.271884  0.657865
# 1104  80.400000        B-
# 1105  84.800000        B+

# %% [markdown]
# ### 3. query函数

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### query函数中的布尔表达式中，下面的符号都是合法的：行列索引名、字符串、and/not/or/&/|/~/not in/in/==/!=、四则运算符

# %%
df.query('(Address in ["street_6","street_7"])&(Weight>(70+10))&(ID in [1303,2304,2402])')
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 2304    S_2   C_3      F  street_6     164      81  95.5      A-
# 2402    S_2   C_4      M  street_7     166      82  48.7       B

# %% [markdown]
# ## 五、重复元素处理
# ### 1. duplicated方法
# #### 该方法返回了是否重复的布尔列表

# %%
df.duplicated('Class').head()
# Out:
# ID
# 1101    False
# 1102     True
# 1103     True
# 1104     True
# 1105     True
# dtype: bool

# %% [markdown]
# #### 可选参数keep默认为first，即首次出现设为不重复，False，若为last，则最后一次设为不重复，若为False，则所有重复项为False

# %%
df.duplicated('Class',keep='last').tail()
# Out:
# ID
# 2401     True
# 2402     True
# 2403     True
# 2404     True
# 2405    False
# dtype: bool

# %%
df.duplicated('Class',keep=False).head()
# Out:
# ID
# 1101    True
# 1102    True
# 1103    True
# 1104    True
# 1105    True
# dtype: bool

# %% [markdown]
# ### 2. drop_duplicates方法
# #### 从名字上看出为剔除重复项，这在后面章节中的分组操作中可能是有用的，例如需要保留每组的第一个值：

# %%
df.drop_duplicates('Class')
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 2401    S_2   C_4      F  street_2     192      62  45.3       A

# %% [markdown]
# #### 参数与duplicate函数类似：

# %%
df.drop_duplicates('Class',keep='last')
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2105    S_2   C_1      M  street_4     170      81  34.2       A
# 2205    S_2   C_2      F  street_7     183      76  85.4       B
# 2305    S_2   C_3      M  street_4     187      73  48.9       B
# 2405    S_2   C_4      F  street_6     193      54  47.6       B

# %% [markdown]
# #### 在传入多列时等价于将多列共同视作一个多级索引，比较重复项：

# %%
df.drop_duplicates(['School','Class'])
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 2101    S_2   C_1      M  street_7     174      84  83.3       C
# 2201    S_2   C_2      M  street_5     193     100  39.1       B
# 2301    S_2   C_3      F  street_4     157      78  72.3      B+
# 2401    S_2   C_4      F  street_2     192      62  45.3       A

# %% [markdown]
# ## 六、抽样函数
# #### 这里的抽样函数指的就是sample函数
# #### （a）n为样本量

# %%
df.sample(n=5)
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2303    S_2   C_3      F  street_7     190      99  65.9       C
# 2405    S_2   C_4      F  street_6     193      54  47.6       B
# 2402    S_2   C_4      M  street_7     166      82  48.7       B
# 1204    S_1   C_2      F  street_5     162      63  33.8       B
# 2201    S_2   C_2      M  street_5     193     100  39.1       B

# %% [markdown]
# #### （b）frac为抽样比

# %%
df.sample(frac=0.05)
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1302    S_1   C_3      F  street_1     175      57  87.7      A-
# 2404    S_2   C_4      F  street_2     160      84  67.7       B

# %% [markdown]
# #### （c）replace为是否放回

# %%
df.sample(n=df.shape[0],replace=True).head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2405    S_2   C_4      F  street_6     193      54  47.6       B
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1302    S_1   C_3      F  street_1     175      57  87.7      A-
# 2105    S_2   C_1      M  street_4     170      81  34.2       A

# %%
df.sample(n=35,replace=True).index.is_unique
# Out:
# False

# %% [markdown]
# #### （d）axis为抽样维度，默认为0，即抽行

# %%
df.sample(n=3,axis=1).head()
# Out:
#        Address School Gender
# ID
# 1101  street_1    S_1      M
# 1102  street_2    S_1      F
# 1103  street_2    S_1      M
# 1104  street_2    S_1      F
# 1105  street_4    S_1      F

# %% [markdown]
# #### （e）weights为样本权重，自动归一化

# %%
df.sample(n=3,weights=np.random.rand(df.shape[0])).head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2405    S_2   C_4      F  street_6     193      54  47.6       B
# 2402    S_2   C_4      M  street_7     166      82  48.7       B
# 2205    S_2   C_2      F  street_7     183      76  85.4       B

# %%
#以某一列为权重，这在抽样理论中很常见
df.sample(n=3,weights=df['Math']).head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2101    S_2   C_1      M  street_7     174      84  83.3       C
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 2403    S_2   C_4      F  street_6     158      60  59.7      B+

# %% [markdown]
# ## 七、问题与练习
